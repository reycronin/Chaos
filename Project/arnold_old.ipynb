# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

def circle(theta, omega, K):
    return (theta + omega - K * np.sin(2 * np.pi * theta)) %1

def get_theta_o(theta_o, omega, K):
    theta_start = []
    theta_start.append(theta_o)
    for i in range(100):
        theta_start.append(circle(theta_start[-1], omega, K))
    return theta_start

def wind(theta_o, omega, K):
    n = 0
    e = .03
    nn = []
    theta_start = get_theta_o(theta_o, omega,K)
    for i in range(len(theta_start)):
        theta = theta_start[i]
        while abs(theta  - theta_start[i]) < e and n < 50:
            theta = circle(theta, omega, K)
            n += 1
        nn.append(n)
    #print('---------')
    return np.mean(nn)

def getwind(OMEGA, K, W, theta_o):
    for i in range(len(K)):
        for j in range(len(K[0])):
            k = K[i][j]
            omega = OMEGA[i][j]
            W[i][j] = wind(theta_o, omega, k)
            #print('done')
    return W            
            
theta_o = .5

dx = .01
y = np.arange(0,1+dx,dx)
x = np.arange(0,1+dx,dx)
OMEGA, K = np.meshgrid(x,y)
W = OMEGA*0.0 
W = getwind(OMEGA, K, W, theta_o)



cc = plt.pcolormesh(OMEGA,K,W, cmap ='gnuplot')
plt.axis('scaled')

cbar = plt.colorbar()
plt.xlabel('$\Omega$')
plt.ylabel('K')
cbar.set_label('number of iterations where |$\Theta - \Theta_o$| $< \epsilon$')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

def circle(theta, omega, K):
    return (theta + omega - K * np.sin(2 * np.pi * theta)) %1

def get_theta_o(theta_o, omega, K):
    theta_start = []
    theta_start.append(theta_o)
    for i in range(100):
        theta_start.append(circle(theta_start[-1], omega, K))
    return theta_start

def wind(theta_o, omega, K):
    e = .01
    nn = []
    theta_start = get_theta_o(theta_o, omega,K)
    for i in range(len(theta_start)):
        theta = theta_start[i]
        theta_curr = theta + 2*e
        n = 0
        while abs(theta_curr  - theta_start[i]) > e and n < 150:
            theta = circle(theta, omega, K)
            theta_curr = theta
            n += 1
        nn.append(n)
    #print('---------')
    return np.mean(nn)

def getwind(OMEGA, K, W, theta_o):
    for j in range(len(K)):
        for i in range(len(K[0])):
            k = K[i][j]
            omega = OMEGA[i][j]
            W[i][j] = wind(theta_o, omega, k)
            #print('done')
    return W            
            
theta_o = .5

dx = .01
y = np.arange(0,1+dx,dx)
x = np.arange(0,1+dx,dx)
OMEGA, K = np.meshgrid(x,y)
W = OMEGA*0.0 
W = getwind(OMEGA, K, W, theta_o)



cc = plt.pcolormesh(OMEGA,K,W, cmap ='gnuplot')
plt.axis('scaled')

cbar = plt.colorbar()
plt.xlabel('$\Omega$')
plt.ylabel('K')
cbar.set_label('number of iterations where |$\Theta - \Theta_o$| $< \epsilon$')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
import random
print (random.randint(0,2500))
# Out:
# 2017

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

def circle(theta, omega, K):
    return (theta + omega - K * np.sin(2 * np.pi * theta)) 

def get_theta_o(theta_o, omega, K):
    theta_start = []
    theta_start.append(theta_o)
    for i in range(10):
        theta_start.append(circle(theta_start[-1], omega, K))
    return theta_start

def get_theta_o_2(theta_o, omega, K):
    theta_start = []
    for i in range(1,500):
        theta_start.append(i/500)
    return theta_start

def get_theta_o_3(theta_o, omega, K):
    theta_start = []
    for i in range(1,500):
        theta_start.append(theta_o)
    return theta_start

def wind(theta_o, omega, K):
    n = 0
    e = .03
    nn = []
    theta_start = get_theta_o_2(theta_o, omega,K)
    for i in range(len(theta_start)):
        theta = theta_start[i]
        theta_curr = theta + 2*e
        while (theta_curr - theta_start[i])%1  > e and n < 200:
            theta = circle(theta, omega, K)
            theta_curr = theta
            n += 1
        nn.append(n)
    return np.min(nn)

def getwind(OMEGA, K, W, theta_o):
    for i in range(len(K)):
        for j in range(len(K[0])):
            k = K[i][j]
            omega = OMEGA[i][j]
            W[i][j] = wind(theta_o, omega, k)
            #print('done')
    return W            
            
theta_o = 0.5

dx = .03
y = np.arange(0,1+dx,dx)
x = np.arange(0,1+dx,dx)
OMEGA, K = np.meshgrid(x,y)
W = OMEGA*0.0 
W = getwind(OMEGA, K, W, theta_o)



cc = plt.pcolormesh(OMEGA,K,W, cmap ='gnuplot')
plt.axis('scaled')

cbar = plt.colorbar()
plt.xlabel('$\Omega$')
plt.ylabel('K')
cbar.set_label('number of iterations where |$\Theta - \Theta_o$| $< \epsilon$')
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %%
print(W)
# Out:
# [[   6.          155.45454545  102.         ...,  136.36363636
#    190.09090909    6.        ]
#  [   6.          200.          177.09090909 ...,  176.          200.          146.        ]
#  [   6.          200.          200.         ...,  200.          200.
#    163.90909091]
#  ...,
#  [   6.          119.90909091  166.09090909 ...,  200.          162.18181818
#    146.        ]
#  [   6.          181.90909091  200.         ...,  200.          126.27272727
#    164.        ]
#  [   6.          181.90909091  200.         ...,  200.          182.18181818
#    181.90909091]]

# %%
theta_start = []
for i in range(1,50):
    theta_start.append(i/50)
print(theta_start)
# Out:
# [0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4, 0.42, 0.44, 0.46, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.6, 0.62, 0.64, 0.66, 0.68, 0.7, 0.72, 0.74, 0.76, 0.78, 0.8, 0.82, 0.84, 0.86, 0.88, 0.9, 0.92, 0.94, 0.96, 0.98]

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

def circle(theta, omega, K):
    return (theta + omega - K * np.sin(2 * np.pi * theta)) %1

def get_theta_o(theta_o, omega, K):
    theta_start = []
    theta_start.append(theta_o)
    for i in range(100):
        theta_start.append(circle(theta_start[-1], omega, K))
    return theta_start

def wind(theta_o, omega, K):
    n = 0
    e = .03
    nn = []
    theta_start = get_theta_o(theta_o, omega,K)
    for i in range(len(theta_start)):
        theta = theta_start[i]
        while abs(theta  - theta_start[i]) < e and n < 50:
            theta = circle(theta, omega, K)
            n += 1
        nn.append(n)
    #print('---------')
    return np.mean(nn)

def getwind(OMEGA, K, W, theta_o):
    for i in range(len(K)):
        for j in range(len(K[0])):
            k = K[i][j]
            omega = OMEGA[i][j]
            W[i][j] = wind(theta_o, omega, k)
            #print('done')
    return W            
            
theta_o = .5

dx = .01
y = np.arange(0,1+dx,dx)
x = np.arange(0,1+dx,dx)
OMEGA, K = np.meshgrid(x,y)
W = OMEGA*0.0 
W = getwind(OMEGA, K, W, theta_o)



cc = plt.pcolormesh(OMEGA,K,W, cmap ='gnuplot')
plt.axis('scaled')

cbar = plt.colorbar()
plt.xlabel('$\Omega$')
plt.ylabel('K')
cbar.set_label('number of iterations where |$\Theta - \Theta_o$| $< \epsilon$')
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %%
X = [[1, 2, 4, 5][ 22, 32 , 3 ,2]]
print(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43