# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MultipleLocator

def circle(theta, omega, K):
    return theta + omega - K * np.sin(2 * np.pi * theta) / (2 * np.pi)

def wind(theta_o, omega, K):
    theta = theta_o
    n = 0
    while n < 250:
        theta = circle(theta, omega, K)
        n += 1
    return ((theta - theta_o)/n) % 1

def getwind(OMEGA, K, W, theta_o):
    for i in range(len(OMEGA)):
        omega = OMEGA[i]
        W[i] = wind(theta_o, omega, K)
    return W

theta_o = .5
K = 1
omega = np.linspace(0,1,10000)
W = omega * 0.0
W = getwind(omega, K, W, theta_o)

plt.plot(omega, W, 'k')
#plt.title('devils staircase')
plt.xlabel('$\Omega$')
plt.ylabel('W')

plt.savefig('devil.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MultipleLocator

def circle(theta, omega, K):
    return theta + omega - K * np.sin(2 * np.pi * theta) / (2 * np.pi)

def wind(theta_o, omega, K):
    theta = theta_o
    n = 0
    while n < 250:
        theta = circle(theta, omega, K)
        n += 1
    return ((theta - theta_o)/n) % 1

def getwind(OMEGA, K, W, theta_o):
    for i in range(len(OMEGA)):
        omega = OMEGA[i]
        W[i] = wind(theta_o, omega, K)
    return W

theta_o = .5
K = 1
omega = np.linspace(0,1,10000)
W = omega * 0.0
W = getwind(omega, K, W, theta_o)

plt.plot(omega[5600:6250], W[5600:6250], 'k')
plt.savefig('zoom.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
