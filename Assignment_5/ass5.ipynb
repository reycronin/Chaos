# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values1 = []
y_values1 = []
z_values1 = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z):
    r = 45
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z

      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    while steps > count :
        
        x_values1.append(x)
        y_values1.append(y)
        z_values1.append(z)
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        count += 1
    '''
    fig = plt.figure()
    ax = plt.axes(projection = '3d')
    ax.scatter(x_values,y_values,z_values, c = 'k')
    plt.show()
    '''
    #ax.plot(x, z, 'r+', zdir='y', zs=1.5)
    #ax.plot(y, z, 'g+', zdir='x', zs=-0.5)
    #ax.plot(x, y, 'k+', zdir='z', zs=-1.5)
    #plt.savefig('Q2a.png')
    plt.plot(x_values1,y_values1,'k,')
    
init = [-13, -12, 52]
t0 = 0
steps = 20000
dt = .001
tol = .00001
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values1 = []
y_values1 = []
z_values1 = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    return -y - z

# y dot
def g(t, x, y, z):
    a = .1
    return x + a * y

# z dot
def h(t, x, y, z):
    b = .1
    c = 14
    return b + z*(x - c)

      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    while steps > count :
        
        x_values1.append(x)
        y_values1.append(y)
        z_values1.append(z)
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        count += 1
    '''
    fig = plt.figure()
    ax = plt.axes(projection = '3d')
    ax.scatter(x_values,y_values,z_values, c = 'k')
    plt.show()
    '''
    #ax.plot(x, z, 'r+', zdir='y', zs=1.5)
    #ax.plot(y, z, 'g+', zdir='x', zs=-0.5)
    #ax.plot(x, y, 'k+', zdir='z', zs=-1.5)
    #plt.savefig('Q2a.png')
    plt.plot(x_values1,z_values1,'k,')
    
init = [-13, -12, 52]
t0 = 0
steps = 100000
dt = .01
tol = .0001
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z):
    r = 45
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z
    
def half_steps(dt, t, x ,y, z):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1

    plt.plot(x_values, z_values, 'k,')
    plt.title('Lorenz System', fontsize = 16)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('z', fontsize = 12)
    plt.tight_layout()
    plt.savefig('Q2a.png')
    


    
init = [-13, -12, 52]
t0 = 0
steps = 10000
dt = .001
tol = .0001
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z):
    r = 45
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z
    
def half_steps(dt, t, x ,y, z):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1

    plt.plot(x_values1,z_values1,'r.', markersize = 2, label = 'nonadaptive')
    plt.plot(x_values, z_values, 'k.', markersize = 2, label = 'adaptive')
    plt.legend(framealpha=1, frameon=True);
    plt.title('Lorenz System', fontsize = 16)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('z', fontsize = 12)
    plt.tight_layout()
    plt.show()
    plt.savefig('Q2b.png')
    


    
init = [-13, -12, 52]
t0 = 0
steps = 20000
dt = .001
tol = .000001
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z, r):
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z
    
def half_steps(dt, t, x ,y, z, r):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z,r)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2,r)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2,r)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt,r )
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol,r):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z,r )
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2,r)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2,r)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt,r)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z, r)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1
            
    print(x, y, z)

    plt.plot(x_values, z_values, 'k,', markersize = 2)
    plt.legend(framealpha=1, frameon=True);
    plt.title('Lorenz System', fontsize = 16)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('z', fontsize = 12)
    plt.tight_layout()
    plt.show()
    


r = 29.5
init = [-14, -12, 52]
t0 = 0
steps = 100000
dt = .001
tol = .000001
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol,r)
# Out:
# -10.677078497380297 -10.677078179725731 28.499999889466476
# <img src="data:image/png;base64,..." width="638.888905813665">
# No handles with labels found to put in legend.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    return -(y + z)

# y dot
def g(t, x, y, z):
    a = .398
    return x + a * y

# z dot
def h(t, x, y, z):
    b = 2
    c = 4
    return b + z * (x - c)
    
def half_steps(dt, t, x ,y, z):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1
            
    '''    plt.plot(y_values, z_values, 'k,')
    plt.title('R$\ddot{o}$ssler System', fontsize = 16)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('y', fontsize = 12)
    plt.tight_layout()
    plt.savefig('Q3.png')
    '''

    fig = plt.figure()
    ax = plt.axes(projection = '3d')
    ax.scatter(x_values[18000:19000],y_values[18000:19000],z_values[18000:19000], c = 'k')
    plt.show()

    
init = [-13, -12, 52]
t0 = 0
steps = 19000
dt = .001
tol = .00001
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z):
    r = 45
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z
    
def half_steps(dt, t, x ,y, z):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1

    plt.plot(x_values, y_values, 'k,')
    plt.title('Lorenz System tol = .4588', fontsize = 12)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('z', fontsize = 12)
    plt.tight_layout()
    plt.savefig('Q4_1.png')
    


    
init = [-13, -12, 52]
t0 = 0
steps = 10000
dt = 0.1
tol = .4588
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z):
    r = 45
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z
    
def half_steps(dt, t, x ,y, z):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1

    plt.plot(x_values, y_values, 'k,')
    plt.title('Lorenz System tol = .4589', fontsize = 12)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('z', fontsize = 12)
    plt.tight_layout()
    plt.savefig('Q4_2.png')
    

    
init = [-13, -12, 52]
t0 = 0
steps = 10000
dt = 0.1
tol = .4589
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_values = []
y_values = []
z_values = []

#runge kutta 4th order

# x dot
def f(t, x, y, z):
    a = 16
    return a * (y - x) 

# y dot
def g(t, x, y, z):
    r = 45
    return r * x - y - x * z

# z dot
def h(t, x, y, z):
    b = 4
    return x * y - b * z
    
def half_steps(dt, t, x ,y, z):
    
    dt = dt/2    
    for i in range(2): 
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        t += dt

    return x, y, z
      
def rk4_adapt(t0, x0, y0, z0, steps, dt, tol):
    t = t0
    x = x0
    y = y0
    z = z0
    count = 0
    count2 = 0
    
    while steps > count:
        
        k1 = f(t, x, y, z)
        l1 = g(t, x, y, z)
        m1 = h(t, x, y ,z)
        
        k2 = f(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        l2 = g(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
        m2 = h(t + dt / 2, x + k1 * dt / 2, y + l1 * dt / 2, z + m1 * dt / 2)
                
        k3 = f(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        l3 = g(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        m3 = h(t + dt / 2, x + k2 * dt / 2, y + l2 * dt / 2, z + m2 * dt / 2)
        
        k4 = f(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        l4 = g(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        m4 = h(t + dt, x + k3 * dt, y + l3 * dt, z + m3 * dt)
        
        x_full = x + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        y_full = y + dt / 6 * (l1 + 2 * l2 + 2 * l3 + l4)
        z_full = z + dt / 6 * (m1 + 2 * m2 + 2 * m3 + m4)
        
        x_half, y_half, z_half = half_steps(dt, t, x ,y, z)
        
        
        
        if max(abs(x_full - x_half), abs(y_full - y_half), abs(z_full - z_half)) <= tol:
            t += dt
            x = x_full
            y = y_full
            z = z_full
            x_values.append(x)
            y_values.append(y)
            z_values.append(z)
            dt = dt * 2 
            count += 1
        else:
            dt = dt/2
            count2 += 1

    plt.plot(x_values, z_values, 'k,')
    plt.title('Lorenz System tol = .5', fontsize = 12)
    plt.xlabel('x', fontsize = 12)
    plt.ylabel('z', fontsize = 12)
    plt.tight_layout()
    plt.savefig('Q4_3.png')
    


    
init = [-13, -12, 52]
t0 = 0
steps = 10000
dt = .01
tol = .05
rk4_adapt(t0, init[0], init[1], init[2], steps, dt, tol)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
