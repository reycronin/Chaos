# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors



def frac_tree_left(n,theta,ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(-theta), start[1] + ll * np.cos(-theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)



def frac_tree_right(n, theta, ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(theta), start[1] + ll * np.cos(theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)
               

    
colors = [mcolors.to_rgba(c)
          for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]
    
n = 10
theta_l = 90
theta_r = 90
ratio_l = .6
ratio_r = .6

lines_r = frac_tree_right(n, theta_r, ratio_r)
lines_l = frac_tree_left(n, theta_l, ratio_l)
lcr = mc.LineCollection(lines_r, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)
lcl = mc.LineCollection(lines_l, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)

y_top = 17
y_bot = -2
x_l = -15
x_r = 15


fig, ax = pl.subplots(figsize = (y_top-y_bot,x_r-x_l))
plt.axis('scaled')
ax.add_collection(lcr)
ax.add_collection(lcl)
#ax.autoscale()

ax.set_xlim(x_l, x_r)
ax.set_ylim(y_bot, y_top)
plt.title('H tree', fontsize = 20)
#ax.margins(1)
ax.autoscale(False)
plt.axis('off')
plt.savefig('Q3a.png')
plt.show()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors



def frac_tree_left(n,theta,ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(-theta), start[1] + ll * np.cos(-theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)



def frac_tree_right(n, theta, ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(theta), start[1] + ll * np.cos(theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)
               

    
colors = [mcolors.to_rgba(c)
          for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]
    
n = 10
theta_l = 60
theta_r = 40
ratio_l = .7
ratio_r = .65

lines_r = frac_tree_right(n, theta_r, ratio_r)
lines_l = frac_tree_left(n, theta_l, ratio_l)
lcr = mc.LineCollection(lines_r, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)
lcl = mc.LineCollection(lines_l, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)

y_top = 24
y_bot = -2
x_l = -15
x_r = 14


fig, ax = pl.subplots(figsize = (y_top-y_bot,x_r-x_l))
plt.axis('scaled')
ax.add_collection(lcr)
ax.add_collection(lcl)
#ax.autoscale()

ax.set_xlim(x_l, x_r)
ax.set_ylim(y_bot, y_top)
plt.title('fractal', fontsize = 34)
ax.autoscale(False)
plt.axis('off')
plt.savefig('Q3c.png')
plt.show()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors



def frac_tree_left(n,theta,ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(-theta), start[1] + ll * np.cos(-theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)



def frac_tree_right(n, theta, ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(theta), start[1] + ll * np.cos(theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)
               

    
colors = [mcolors.to_rgba(c)
          for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]
    
n = 10
theta_l = 90
theta_r = 90
ratio_l = 1/np.sqrt(2)+.03
ratio_r = 1/np.sqrt(2)+.03

lines_r = frac_tree_right(n, theta_r, ratio_r)
lines_l = frac_tree_left(n, theta_l, ratio_l)
lcr = mc.LineCollection(lines_r, linewidths=1, colors = colors, linestyle='solid', linewidth=2)
lcl = mc.LineCollection(lines_l, linewidths=1, colors = colors, linestyle='solid', linewidth=2)

y_top = 17
y_bot = -2
x_l = -15
x_r = 15


fig, ax = pl.subplots(figsize = (y_top-y_bot,x_r-x_l))
plt.axis('scaled')
ax.add_collection(lcr)
ax.add_collection(lcl)
#ax.autoscale()

ax.set_xlim(x_l, x_r)
ax.set_ylim(y_bot, y_top)
plt.title('H tree', fontsize = 20)
#ax.margins(1)
ax.autoscale(False)
plt.axis('off')
plt.show()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors



def frac_tree_left(n,theta,ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(-theta), start[1] + ll * np.cos(-theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)



def frac_tree_right(n, theta, ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(theta), start[1] + ll * np.cos(theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)
               

    
colors = [mcolors.to_rgba(c)
          for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]
    
n = 10
theta_l = 95
theta_r = 95
ratio_l = 1/np.sqrt(2)
ratio_r = 1/np.sqrt(2)

lines_r = frac_tree_right(n, theta_r, ratio_r)
lines_l = frac_tree_left(n, theta_l, ratio_l)
lcr = mc.LineCollection(lines_r, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)
lcl = mc.LineCollection(lines_l, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)

y_top = 17
y_bot = -1
x_l = -12
x_r = 12

fig, ax = pl.subplots(figsize = (y_top-y_bot,x_r-x_l))
plt.axis('scaled')
ax.add_collection(lcr)
ax.add_collection(lcl)
#ax.autoscale()

ax.set_xlim(x_l, x_r)
ax.set_ylim(y_bot, y_top)
plt.title('interesting fractal', fontsize = 25)
ax.autoscale(False)
plt.axis('off')
plt.savefig('Q3d_1.png')
plt.show()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors


def frac_tree_left(n,theta,ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(-theta), start[1] + ll * np.cos(-theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)



def frac_tree_right(n, theta, ratio):
    # summation 2^n
    lines = np.zeros((2**(n+1), 2, 2))
    theta = np.radians(theta)
    ll = 5
    lines[0] = [[0, 0], [0, 10]]
    start = lines[0][1]
    lines[1] = [[start[0], start[1]], [start[0] +  ll * np.sin(theta), start[1] + ll * np.cos(theta) ]]
    for i in range(1,n+1):
        ll = ll * ratio            
        count = 0
        for j in range(0,2**i,2):
            prev_start = lines[2**(i-1) + count][0]
            start = lines[2**(i-1) + count][1]
            prev_theta = np.arctan2(start[1]-prev_start[1],start[0]-prev_start[0])
            x = ll * np.cos(prev_theta)
            y = ll * np.sin(prev_theta)
            xp = np.cos(theta) * x - np.sin(theta) * y
            yp = np.sin(theta) * x + np.cos(theta) * y
            xp2 = np.cos(-theta) * x - np.sin(-theta) * y
            yp2 = np.sin(-theta) * x + np.cos(-theta) * y            
            lines[2**i+j] = [[start[0], start[1]], [start[0] + xp, start[1] + yp]]
            lines[2**i+j+1] = [[start[0], start[1]], [start[0] + xp2, start[1] + yp2]]
            count += 1                         
    return(lines)
               

    
colors = [mcolors.to_rgba(c)
          for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]
    
n = 12
theta_l = 20
theta_r = 20
ratio_l = .6
ratio_r = .8

lines_r = frac_tree_right(n, theta_r, ratio_r)
lines_l = frac_tree_left(n, theta_l, ratio_l)
lcr = mc.LineCollection(lines_r, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)
lcl = mc.LineCollection(lines_l, linewidths=1, colors = 'k', linestyle='solid', linewidth=2)

y_top = 35
y_bot = -1
x_l = -12
x_r = 20

fig, ax = pl.subplots(figsize = (y_top-y_bot,x_r-x_l))
plt.axis('scaled')
ax.add_collection(lcr)
ax.add_collection(lcl)
#ax.autoscale()

ax.set_xlim(x_l, x_r)
ax.set_ylim(y_bot, y_top)
plt.title('interesting fractal', fontsize = 40)
ax.autoscale(False)
plt.axis('off')
plt.savefig('Q3d_2.png')

plt.show()
